# %%
import pandas as pd
import PIL
import glob
import re
import random

# %%
# def target(i):
#   s = i
#   ss = re.findall("n[0-9]+", s) #regular expression to extract the target value
#   # +atleat one or more
#   #*0 or more occurance
#   return (ss)

# # l=glob.glob("/content/drive/MyDrive/Data/MindBigData-Imagenet-v1.0-Imgs")
# # print(l)
# # dfs=[]

# #l = random.sample(l,100)
# #l=listt
# # dfs=[]
# # df_empty =  pd.DataFrame()
# # shape=0
# # for i,path in enumerate(l): # iterate through files
  
# #     print("file_count:",i)      #No. files traversed
# #     df=pd.read_csv(path,header=None)
# #     df=df.transpose()           # to transform the data from rows to column
# #     print("path:",path)
# #     shape+=df.shape[0]
# #     print("shape:",shape)       #shape counter
# #     result=df_empty.append(df)  #buffer step
# #     result.columns = result.iloc[0]
# #     result["target"]=target(path)[0] # adding the target to the dataframe
# #     result.drop(index=result.index[0], axis=0, inplace=True)
# #     dfs.append(result)
# # final =  pd.DataFrame()  #concating all the files into one
# # c=0
# # for i in dfs:
# #         c=c+1
# #         print("file_count",c)  #No. files traversed
# #         final = pd.concat(  [final, i], axis=0)
# #         final.reset_index(inplace=True, drop=True) 
# # #saving to the same local directory
# # final.to_csv(r"short_data.csv")

# %%
# import OS module
import os
 
# Get the list of all files and directories
path = "/content/drive/MyDrive/Data/MindBigData-Imagenet-v1.0-Imgs"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
# prints all files
print(dir_list)
# Out:
# Files and directories in ' /content/drive/MyDrive/Data/MindBigData-Imagenet-v1.0-Imgs ' :
# ...

# %%
def target(i):
  s = i
  ss = re.findall("n[0-9]+", s) #regular expression to extract the target value
  # +atleat one or more
  #*0 or more occurance
  return (ss)
t=[]
for fname in dir_list:
  tname=target(fname)[0]
  t.append(tname)

# %%
df = pd.DataFrame(dir_list,columns=["path"])
df["target"]=t
df
# Out:
#                                                     path     target
# 0      MindBigData_Imagenet_Insight_n04356056_9702_1_...  n04356056
# 1      MindBigData_Imagenet_Insight_n04356056_9965_1_...  n04356056
# 2      MindBigData_Imagenet_Insight_n04357314_10184_1...  n04357314
# 3      MindBigData_Imagenet_Insight_n04357314_13316_1...  n04357314
# 4      MindBigData_Imagenet_Insight_n04357314_13439_1...  n04357314
# ...                                                  ...        ...
# 10027  MindBigData_Imagenet_Insight_n00141669_965_1_7...  n00141669
# 10028  MindBigData_Imagenet_Insight_n00477639_10341_1...  n00477639
# 10029  MindBigData_Imagenet_Insight_n00477639_11246_1...  n00477639
# 10030  MindBigData_Imagenet_Insight_n00477639_11386_1...  n00477639
# 10031  MindBigData_Imagenet_Insight_n00477639_12620_1...  n00477639
#
# [10032 rows x 2 columns]

# %%
df["target"].value_counts()
# Out:
# n01776313    34
# n02101388    33
# n01674464    32
# n02012849    31
# n02411705    30
#              ..
# n02111500     8
# n02108422     7
# n01693334     7
# n02089973     7
# n02687172     6
# Name: target, Length: 569, dtype: int64

# %%
import pandas as pd

df_word=pd.read_csv("/content/drive/MyDrive/Data/classes_V01.txt",sep="\t",header=None)

df_word.columns=['name','repetition','target','category']
df_word
# Out:
#                                                   name  ...         category
# 0    domestic cat, house cat, Felis domesticus, Fel...  ...          Mammals
# 1                rock python, rock snake, Python sebae  ...          Reptile
# 2                                            Chihuahua  ...          Mammals
# 3                              flute, transverse flute  ...  MusicInstrument
# 4         grey fox, gray fox, Urocyon cinereoargenteus  ...          Mammals
# ..                                                 ...  ...              ...
# 564                                           keeshond  ...          Mammals
# 565                            corkscrew, bottle screw  ...      KitchenWare
# 566                              Angora, Angora rabbit  ...          Mammals
# 567                                       coffee maker  ...      Electronics
# 568                                     pot, flowerpot  ...      KitchenWare
#
# [569 rows x 4 columns]

# %%
df_word.category.unique()
# Out:
# array(['Mammals', 'Reptile', 'MusicInstrument', 'Furniture', 'Clothe',
#        'Bird', 'Vehicle', 'Sports', 'Place', 'Road', 'KitchenWare',
#        'Human', 'shipboat', 'amphibian', 'Tool', 'Stationary',
#        'Electronics', 'Insect', 'arachnids', 'MedicalInstrument', 'Fruit',
#        'Cosmetics', 'Food', 'Fish', 'Arthropods', 'Event', 'Vegitable',
#        'Asteroidea', 'Airport'], dtype=object)

# %%
target_dict={"Animals":["Mammals","Bird","Reptile","Fish","amphibian","Asteroidea","Arthropods","arachnids","Insect"],
             "Tool":["Tool","MusicInstrument","MedicalInstrument","Stationary"],
             "Fashion":["Clothe","Cosmetics"],
             "Home_Appliances":["KitchenWare","Electronics","Furniture"],
             "Transport":["Vehicle","shipboat"],
             "Sports":["Sports"],
             "Place":["Road","Place","Airport","Event"],
             "Food":["Fruit","Food","Vegitable"],
             "Human":["Human"]            
             }

# %%
lst=["Mammals","Bird","Reptile","Fish","amphibian","Airport","Event","Human"]

# %%
word="Airport"

def find_and_replace(word):
  target_dict={"Animals":["Mammals","Bird","Reptile","Fish","amphibian","Asteroidea","Arthropods","arachnids","Insect"],
             "Tool":["Tool","MusicInstrument","MedicalInstrument","Stationary"],
             "Fashion":["Clothe","Cosmetics"],
             "Home_Appliances":["KitchenWare","Electronics","Furniture"],
             "Transport":["Vehicle","shipboat"],
             "Sports":["Sports"],
             "Place":["Road","Place","Airport","Event"],
             "Food":["Fruit","Food","Vegitable"],
             "Human":["Human"]            
             }
  list_list=[]
  for i in target_dict.values():
    list_list.append(i)
  for n in range(len(list_list)):
     if word in list_list[n]:
      key_index=n
  keys_list = list(target_dict)
  key = keys_list[key_index]
  return key

# %%
new_word=find_and_replace(word)
print("_"*100)
print(new_word)
# Out:
# ____________________________________________________________________________________________________
# Place

# %%
new_lst=[]
for word in lst:
  new_word=find_and_replace(word)
  new_lst.append(new_word)
new_lst
# Out:
# ['Animals',
#  'Animals',
#  'Animals',
#  'Animals',
#  'Animals',
#  'Place',
#  'Place',
#  'Human']

# %%
category=[]
for i in df_word.category:
  print(i)
  i=find_and_replace(i)
  category.append(i)
df_word.category=category
# Out:
# Mammals
# Reptile
# Mammals
# MusicInstrument
# Mammals
# Furniture
# Mammals
# Clothe
# Mammals
# Bird
# Mammals
# Vehicle
# Sports
# Place
# Road
# Mammals
# Mammals
# KitchenWare
# Mammals
# Vehicle
# Human
# MusicInstrument
# shipboat
# Mammals
# amphibian
# Mammals
# Mammals
# Bird
# Clothe
# Mammals
# Tool
# Vehicle
# shipboat
# Furniture
# Mammals
# Mammals
# Vehicle
# Human
# Sports
# Mammals
# shipboat
# Furniture
# Mammals
# Mammals
# Mammals
# Reptile
# Stationary
# Vehicle
# Mammals
# Electronics
# Bird
# KitchenWare
# Place
# Mammals
# Mammals
# Bird
# MusicInstrument
# Electronics
# Stationary
# Bird
# Furniture
# Mammals
# MusicInstrument
# Insect
# Mammals
# Reptile
# Sports
# Mammals
# Mammals
# Mammals
# Mammals
# Electronics
# Sports
# Mammals
# Bird
# Place
# Mammals
# Mammals
# Furniture
# Mammals
# Bird
# arachnids
# Mammals
# Mammals
# shipboat
# Mammals
# Mammals
# Mammals
# MedicalInstrument
# MusicInstrument
# Fruit
# Mammals
# Mammals
# Mammals
# Reptile
# ...

# %%
df_word.category.unique()
# Out:
# array(['Animals', 'Tool', 'Home_Appliances', 'Fashion', 'Transport',
#        'Sports', 'Place', 'Human', 'Food'], dtype=object)

# %%
import matplotlib.pyplot as plt

df_word['category'].value_counts().plot(kind='bar')#class density

# %%
df = df.merge(df_word.drop(['name','repetition'],axis=1), how = 'inner', on = ['target'])
df
# Out:
#                                                     path     target category
# 0      MindBigData_Imagenet_Insight_n04356056_9702_1_...  n04356056  Fashion
# 1      MindBigData_Imagenet_Insight_n04356056_9965_1_...  n04356056  Fashion
# 2      MindBigData_Imagenet_Insight_n04356056_1422_1_...  n04356056  Fashion
# 3      MindBigData_Imagenet_Insight_n04356056_1470_1_...  n04356056  Fashion
# 4      MindBigData_Imagenet_Insight_n04356056_1654_1_...  n04356056  Fashion
# ...                                                  ...        ...      ...
# 10027  MindBigData_Imagenet_Insight_n00141669_7753_1_...  n00141669    Place
# 10028  MindBigData_Imagenet_Insight_n00141669_5162_1_...  n00141669    Place
# 10029  MindBigData_Imagenet_Insight_n00141669_8024_1_...  n00141669    Place
# 10030  MindBigData_Imagenet_Insight_n00141669_889_1_3...  n00141669    Place
# 10031  MindBigData_Imagenet_Insight_n00141669_965_1_7...  n00141669    Place
#
# [10032 rows x 3 columns]

# %%
df = df.sample(frac = 1,random_state=2021)
df
# Out:
#                                                    path  ...         category
# 8832  MindBigData_Imagenet_Insight_n02009229_5073_1_...  ...          Animals
# 4280  MindBigData_Imagenet_Insight_n02423022_2089_1_...  ...          Animals
# 6833  MindBigData_Imagenet_Insight_n02108089_428_1_1...  ...          Animals
# 7703  MindBigData_Imagenet_Insight_n02093256_10082_1...  ...          Animals
# 3572  MindBigData_Imagenet_Insight_n03063599_4221_1_...  ...  Home_Appliances
# ...                                                 ...  ...              ...
# 3934  MindBigData_Imagenet_Insight_n03211117_5504_1_...  ...  Home_Appliances
# 2669  MindBigData_Imagenet_Insight_n03710721_15444_1...  ...          Fashion
# 1152  MindBigData_Imagenet_Insight_n03891251_269_1_3...  ...  Home_Appliances
# 6201  MindBigData_Imagenet_Insight_n02099429_6052_1_...  ...          Animals
# 9332  MindBigData_Imagenet_Insight_n01592084_2919_1_...  ...          Animals
#
# [10032 rows x 3 columns]

# %%
        # # <class 'numpy.ndarray'>
        # print(type(img_numpy_array))

        # # type: float32
        # print("type:", img_numpy_array.dtype)

        # # shape: (200, 400, 3)
        # print("shape:", img_numpy_array.shape)

# # convert back to image
# img_pil_from_numpy_array = array_to_img(img_numpy_array)

# # <class 'PIL.PngImagePlugin.PngImageFile'>
# print("converting NumPy array into image:",
# 	type(img_pil_from_numpy_array))

# %%
def img_to_3D(img_name):
        from keras.preprocessing.image import load_img
        import warnings
        from keras.preprocessing.image import img_to_array
        from keras.preprocessing.image import array_to_img
        # load the image via load_img function
        path='/content/drive/MyDrive/Data/MindBigData-Imagenet-v1.0-Imgs/'
        img = load_img(path+img_name)

        # convert the given image into numpy array
        img_numpy_array = img_to_array(img)
        return img_numpy_array
x=img_to_3D("MindBigData_Imagenet_Insight_n04356056_9702_1_908.png") 
x
# Out:
# array([[[ 47.,  81.,  79.],
#         [  0.,  26.,  79.],
#         [ 76.,  84.,  91.],
#         ...,
#         [ 67.,  89.,  49.],
#         [ 50.,  19.,  80.],
#         [ 36.,  71.,  43.]],
#
#        [[ 38.,  74.,  68.],
#         [ 12.,   9.,  68.],
#         [ 70.,  75.,  83.],
#         ...,
#         [ 64.,  87.,  44.],
#         [ 45.,  15.,  77.],
#         [ 29.,  68.,  37.]],
#
#        [[ 36.,  71.,  67.],
#         [ 11.,  11.,  68.],
#         [ 70.,  76.,  84.],
#         ...,
#         [ 67.,  86.,  50.],
#         [ 51.,  14.,  80.],
#         [ 37.,  67.,  45.]],
#
#        ...,
#
#        [[252., 252., 254.],
#         [252., 252., 254.],
#         [252., 252., 254.],
#         ...,
#         [205., 156., 211.],
#         [223., 195., 220.],
#         [229., 204., 230.]],
#
#        [[252., 252., 243.],
#         [252., 250., 239.],
#         [251., 249., 233.],
#         ...,
#         [251., 253., 252.],
#         [251., 252., 252.],
# ...

# %%
count=0
array_3D=[]

for fname in df.path:
  count=count+1
  print("file count",count)
  x=img_to_3D(fname) 
  array_3D.append(x)
df["3D"]=array_3D
# Out:
# Streaming output truncated to the last 5000 lines.
# file count 5033
# file count 5034
# file count 5035
# file count 5036
# file count 5037
# file count 5038
# file count 5039
# file count 5040
# file count 5041
# file count 5042
# file count 5043
# file count 5044
# file count 5045
# file count 5046
# file count 5047
# file count 5048
# file count 5049
# file count 5050
# file count 5051
# file count 5052
# file count 5053
# file count 5054
# file count 5055
# file count 5056
# file count 5057
# file count 5058
# file count 5059
# file count 5060
# file count 5061
# file count 5062
# file count 5063
# file count 5064
# file count 5065
# file count 5066
# file count 5067
# file count 5068
# file count 5069
# file count 5070
# file count 5071
# file count 5072
# file count 5073
# file count 5074
# file count 5075
# file count 5076
# file count 5077
# file count 5078
# file count 5079
# file count 5080
# file count 5081
# file count 5082
# file count 5083
# file count 5084
# ...

# %%
import numpy as np

X = np.array(df["3D"].tolist())
Y=np.array(df["category"].tolist())

# %%
X
# Out:
# array([[[[ 17.,  89.,   0.],
#          [ 33., 102.,  25.],
#          [ 10.,  29.,  61.],
#          ...,
#          [ 64.,  16.,  66.],
#          [ 16.,   5.,  72.],
#          [ 58.,  42.,  27.]],
#
#         [[ 40.,  97.,   4.],
#          [ 22.,  97.,  32.],
#          [ 16.,  65.,  64.],
#          ...,
#          [ 54.,   3.,  73.],
#          [  1.,   5.,  78.],
#          [ 46.,  24.,  40.]],
#
#         [[ 51., 104.,  15.],
#          [ 25.,  92.,  27.],
#          [ 29.,  82.,  59.],
#          ...,
#          [ 45.,   6.,  64.],
#          [  2.,   3.,  70.],
#          [ 38.,  32.,  23.]],
#
#         ...,
#
#         [[248., 249., 253.],
#          [247., 248., 253.],
#          [247., 248., 253.],
#          ...,
#          [216., 224., 213.],
#          [218., 224., 225.],
#          [212., 224., 236.]],
#
#         [[253., 253., 242.],
#          [253., 253., 243.],
#          [253., 253., 243.],
#          ...,
#          [244., 243., 253.],
# ...

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers, utils
import matplotlib.pyplot as plt
from sklearn import metrics 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #resampling

# %%
le = LabelEncoder()
Y = le.fit_transform(Y)

# %%
orig_shape = X.shape

#take backup
X_orig=X.copy()
Y_orig=Y.copy()

print(orig_shape)
X = np.reshape(X, (X.shape[0],-1))
X.shape #after reshaping
# Out:
# (10032, 64, 64, 3)
# (10032, 12288)

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
import collections, numpy

def print_counter(y_data):
  counter = Counter(Y)
  for k,v in counter.items():
    per = v / len(Y) * 100
    print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
  #plot the distribution of classes
  plt.bar(counter.keys(), counter.values())
  plt.show()

# %%
print_counter(Y) #original y distribution
# Out:
# Class=0, n=5563 (55.453%)
# Class=3, n=1225 (12.211%)
# Class=1, n=341 (3.399%)
# Class=7, n=717 (7.147%)
# Class=8, n=857 (8.543%)
# Class=2, n=433 (4.316%)
# Class=4, n=105 (1.047%)
# Class=5, n=372 (3.708%)
# Class=6, n=419 (4.177%)

# %%
count_class=collections.Counter(Y)
print(count_class) #occurances of all classes
count_class[0] #number of occurances of class 0
# Out:
# Counter({0: 5563, 3: 1225, 8: 857, 7: 717, 2: 433, 6: 419, 5: 372, 1: 341, 4: 105})
# 5563

# %%
int(count_class[0]*25/100)  #retain 25% of data from 0 with 0 class
# Out:
# 1390

# %% [markdown]
# ##undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler({0:int(count_class[0]*25/100)},random_state=0)
rus.fit(X, Y)
X, Y = rus.fit_resample(X, Y)


print_counter(Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Class=0, n=1390 (23.724%)
# Class=1, n=341 (5.820%)
# Class=2, n=433 (7.390%)
# Class=3, n=1225 (20.908%)
# Class=4, n=105 (1.792%)
# Class=5, n=372 (6.349%)
# Class=6, n=419 (7.151%)
# Class=7, n=717 (12.238%)
# Class=8, n=857 (14.627%)

# %% [markdown]
# #oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=0)
ros.fit(X, Y)
X, Y = ros.fit_resample(X, Y)

print_counter(Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Class=0, n=1390 (11.111%)
# Class=1, n=1390 (11.111%)
# Class=2, n=1390 (11.111%)
# Class=3, n=1390 (11.111%)
# Class=4, n=1390 (11.111%)
# Class=5, n=1390 (11.111%)
# Class=6, n=1390 (11.111%)
# Class=7, n=1390 (11.111%)
# Class=8, n=1390 (11.111%)

# %%
new_shape=(X.shape[0],orig_shape[1],orig_shape[2],orig_shape[3])
new_shape
# Out:
# (12510, 64, 64, 3)

# %%
X = np.reshape(X, new_shape)
print(X.shape)
# Out:
# (12510, 64, 64, 3)

# %%
X=X 
Y=Y
#categorical label encoding 
le = LabelEncoder()     
YY = tf.keras.utils.to_categorical(le.fit_transform(Y))#
#yy = tf.keras.utils.to_categorical(le.fit_transform(y))

# %%
#train test split
from sklearn.model_selection import train_test_split 

X_train, X_test, Y_train, Y_test = train_test_split(X, YY, test_size=0.2, random_state = 42)

# %%
# import the necessary packages
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers.experimental import preprocessing
import matplotlib.pyplot as plt
import tensorflow as tf
import argparse
from keras.layers.core import Dense, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Embedding
from tensorflow import keras

# %%
# # construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-p", "--plot", type=str, default="training_plot.png",
# 	help="path to output training history plot")
# args = vars(ap.parse_args())
# Out:
# usage: ipykernel_launcher.py [-h] [-p PLOT]
# ipykernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-9fc67f46-3b0a-4b29-9299-062730b8bb39.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# define training hyperparameters
BATCH_SIZE = 64
EPOCHS = 50

# %%
# initialize our sequential data augmentation pipeline for training
trainAug = Sequential([
	preprocessing.Rescaling(scale=1.0 / 255),
	preprocessing.RandomFlip("horizontal_and_vertical"),
	preprocessing.RandomZoom(
		height_factor=(-0.05, -0.15),
		width_factor=(-0.05, -0.15)),
	preprocessing.RandomRotation(0.3)
])
# initialize a second data augmentation pipeline for testing (this
# one will only do pixel intensity rescaling
testAug = Sequential([
	preprocessing.Rescaling(scale=1.0 / 255)
])

# %%
# prepare the training data pipeline (notice how the augmentation
# layers have been mapped)
trainDS = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
trainDS = (
	trainDS
	.shuffle(BATCH_SIZE * 100)
	.batch(BATCH_SIZE)
	.map(lambda x, y: (trainAug(x), y),
		 num_parallel_calls=tf.data.AUTOTUNE)
	.prefetch(tf.data.AUTOTUNE)
)
# create our testing data pipeline (notice this time that we are
# *not* apply data augmentation)
testDS = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
testDS = (
	testDS
	.batch(BATCH_SIZE)
	.map(lambda x, y: (testAug(x), y),
		num_parallel_calls=tf.data.AUTOTUNE)
	.prefetch(tf.data.AUTOTUNE)
)

# %%
#Adding extra dimension to the data
X_train_r = X_train.reshape(X_train.shape[0], 64, 64, 3)
X_test_r = X_test.reshape(X_test.shape[0], 64, 64, 3)

num_labels = YY.shape[1]   #no. of labels

# %% [markdown]
# #model 1

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=2, input_shape=(64,64,3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.GlobalAveragePooling2D())
#
model.add(tf.keras.layers.Dense(9, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
keras.utils.plot_model(model, show_shapes=True)   #visual representation of summary

#model.summary()

# %%
num_epochs = 2000
num_batch_size = 256
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
# fit model
history1 = model.fit(X_train_r, Y_train, epochs=num_epochs, batch_size=num_batch_size, validation_data=(X_test_r, Y_test), verbose=1, callbacks=[es])
# Out:
# Epoch 1/2000
# 313/313 [==============================] - 33s 101ms/step - loss: 5.2579 - accuracy: 0.1172 - val_loss: 2.1997 - val_accuracy: 0.1211
# Epoch 2/2000
# 313/313 [==============================] - 31s 98ms/step - loss: 2.2492 - accuracy: 0.1102 - val_loss: 2.1972 - val_accuracy: 0.1067
# Epoch 3/2000
# 313/313 [==============================] - 31s 99ms/step - loss: 2.2046 - accuracy: 0.1143 - val_loss: 2.1975 - val_accuracy: 0.1019
# Epoch 4/2000
# 313/313 [==============================] - 31s 99ms/step - loss: 2.1974 - accuracy: 0.1126 - val_loss: 2.1975 - val_accuracy: 0.1007
# Epoch 5/2000
# 313/313 [==============================] - 31s 98ms/step - loss: 2.1972 - accuracy: 0.1100 - val_loss: 2.1973 - val_accuracy: 0.0995
# Epoch 6/2000
# 313/313 [==============================] - 31s 98ms/step - loss: 2.1959 - accuracy: 0.1172 - val_loss: 2.1973 - val_accuracy: 0.1015
# Epoch 7/2000
# ...

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# %%
train_loss, train_acc = model.evaluate(X_train, Y_train)

print("Train accuracy", train_acc)
print("Train loss", train_loss)

test_loss, test_acc = model.evaluate(X_test, Y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 9s 28ms/step - loss: 2.1946 - accuracy: 0.1157
# Train accuracy 0.11570743471384048
# Train loss 2.194626808166504
# 79/79 [==============================] - 2s 28ms/step - loss: 2.1976 - accuracy: 0.1023
# Test accuracy 0.10231814533472061
# Test loss 2.1975715160369873

# %% [markdown]
# with data augumentation

# %%
history2 = model.fit(trainDS, epochs=num_epochs,  batch_size=num_batch_size ,validation_data=testDS, verbose=1, callbacks=[es])
# Out:
# Epoch 1/2000
# 157/157 [==============================] - 35s 224ms/step - loss: 2.1972 - accuracy: 0.1155 - val_loss: 2.1982 - val_accuracy: 0.0971
# Epoch 2/2000
# 157/157 [==============================] - 35s 225ms/step - loss: 2.1971 - accuracy: 0.1129 - val_loss: 2.1978 - val_accuracy: 0.1015
# Epoch 3/2000
# 157/157 [==============================] - 36s 227ms/step - loss: 2.1969 - accuracy: 0.1123 - val_loss: 2.1983 - val_accuracy: 0.1007
# Epoch 4/2000
# 157/157 [==============================] - 36s 226ms/step - loss: 2.1969 - accuracy: 0.1130 - val_loss: 2.1979 - val_accuracy: 0.1163
# Epoch 5/2000
# 157/157 [==============================] - 36s 226ms/step - loss: 2.1967 - accuracy: 0.1126 - val_loss: 2.1979 - val_accuracy: 0.1007
# Epoch 6/2000
# 157/157 [==============================] - 36s 227ms/step - loss: 2.1965 - accuracy: 0.1129 - val_loss: 2.1981 - val_accuracy: 0.1019
# Epoch 7/2000
# ...

# %%
train_loss, train_acc = model.evaluate(trainDS)

print("Train accuracy", train_acc)
print("Train loss", train_loss)

test_loss, test_acc = model.evaluate(testDS)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 157/157 [==============================] - 15s 92ms/step - loss: 2.1958 - accuracy: 0.1175
# Train accuracy 0.1175059974193573
# Train loss 2.195847511291504
# 40/40 [==============================] - 2s 54ms/step - loss: 2.1982 - accuracy: 0.1139
# Test accuracy 0.11390887200832367
# Test loss 2.1981990337371826

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# %% [markdown]
# #model 2

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

model2 = Sequential()
model2.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(64,64,3)))
model2.add(BatchNormalization())

model2.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.25))

model2.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.25))

model2.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.25))

model2.add(Flatten())

model2.add(Dense(512, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.5))

model2.add(Dense(128, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.5))

model2.add(Dense(9, activation='softmax'))

# %%
model2.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
keras.utils.plot_model(model2, show_shapes=True)   #visual representation of summary

#model2.summary()

# %%
num_epochs = 2000
num_batch_size = 256
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
# fit model
history3 = model2.fit(X_train_r, Y_train, epochs=num_epochs,  batch_size=num_batch_size, validation_data=(X_test_r, Y_test), verbose=1, callbacks=[es])
# Out:
# Epoch 1/2000
# 313/313 [==============================] - 267s 850ms/step - loss: 2.7027 - accuracy: 0.1655 - val_loss: 2.2777 - val_accuracy: 0.2174
# Epoch 2/2000
# 313/313 [==============================] - 265s 848ms/step - loss: 2.0573 - accuracy: 0.2882 - val_loss: 1.9060 - val_accuracy: 0.3062
# Epoch 3/2000
# 313/313 [==============================] - 265s 847ms/step - loss: 1.6724 - accuracy: 0.4096 - val_loss: 1.6549 - val_accuracy: 0.4524
# Epoch 4/2000
# 313/313 [==============================] - 266s 849ms/step - loss: 1.3857 - accuracy: 0.5195 - val_loss: 1.4453 - val_accuracy: 0.5200
# Epoch 5/2000
# 313/313 [==============================] - 266s 852ms/step - loss: 1.1849 - accuracy: 0.5918 - val_loss: 1.1118 - val_accuracy: 0.6047
# Epoch 6/2000
# 313/313 [==============================] - 267s 853ms/step - loss: 1.0606 - accuracy: 0.6319 - val_loss: 1.0900 - val_accuracy: 0.6267
# Epoch 7/2000
# ...

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# %%
train_loss, train_acc = model2.evaluate(X_train, Y_train)

print("Train accuracy", train_acc)
print("Train loss", train_loss)

test_loss, test_acc = model2.evaluate(X_test, Y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 55s 175ms/step - loss: 0.1343 - accuracy: 0.9753
# Train accuracy 0.9753197431564331
# Train loss 0.1343400925397873
# 79/79 [==============================] - 14s 173ms/step - loss: 0.9341 - accuracy: 0.7446
# Test accuracy 0.7446042895317078
# Test loss 0.9340630173683167

# %%
history4 = model2.fit(trainDS, epochs=num_epochs, batch_size=num_batch_size,validation_data=testDS, verbose=1, callbacks=[es])
# Out:
# Epoch 1/2000
# 157/157 [==============================] - 258s 2s/step - loss: 2.2431 - accuracy: 0.1190 - val_loss: 2.2688 - val_accuracy: 0.1131
# Epoch 2/2000
# 157/157 [==============================] - 258s 2s/step - loss: 2.2234 - accuracy: 0.1215 - val_loss: 2.2734 - val_accuracy: 0.1131
# Epoch 3/2000
# 157/157 [==============================] - 259s 2s/step - loss: 2.2112 - accuracy: 0.1159 - val_loss: 2.1966 - val_accuracy: 0.1267
# Epoch 4/2000
# 157/157 [==============================] - 260s 2s/step - loss: 2.2094 - accuracy: 0.1262 - val_loss: 2.1477 - val_accuracy: 0.1807
# Epoch 5/2000
# 157/157 [==============================] - 260s 2s/step - loss: 2.2042 - accuracy: 0.1256 - val_loss: 2.1344 - val_accuracy: 0.2590
# Epoch 6/2000
# 157/157 [==============================] - 260s 2s/step - loss: 2.2015 - accuracy: 0.1257 - val_loss: 2.1405 - val_accuracy: 0.1851
# Epoch 7/2000
# ...

# %%
train_loss, train_acc = model2.evaluate(trainDS)

print("Train accuracy", train_acc)
print("Train loss", train_loss)

test_loss, test_acc = model2.evaluate(testDS)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 157/157 [==============================] - 61s 379ms/step - loss: 2.1799 - accuracy: 0.1423
# Train accuracy 0.14228616654872894
# Train loss 2.1799237728118896
# 40/40 [==============================] - 14s 334ms/step - loss: 2.1495 - accuracy: 0.1863
# Test accuracy 0.18625099956989288
# Test loss 2.149484395980835

# %%
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
